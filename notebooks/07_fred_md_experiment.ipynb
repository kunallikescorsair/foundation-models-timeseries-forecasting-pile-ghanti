# %% [markdown]
# # 08 — Australian Electricity Demand Model Experiment
#
# This notebook validates the final experiment pipeline on one dataset before scaling to all datasets on HPC.
#
# Experiment unit:
#
# dataset × model × horizon type × horizon
#
# This notebook records:
# - MAE
# - RMSE
# - sMAPE
# - fit time
# - inference time
# - total runtime
# - peak memory usage

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parents[0]

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Project root:", project_root)
# Out:
# Project root: /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

from src.data.dataset_loader import load_monash_dataset
from src.experiments.run_model_experiment import run_model_experiment
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
DATASET_KEY = "fred_md"

MODELS = [
    "naive",
    "seasonal_naive",
    "arima",
    "prophet",
    "lstm",
    "timesfm",
    "ttm",
    "uni2ts",
]

OUTPUT_DIR = Path("results/raw_runs")

# %%
bundle = load_monash_dataset(DATASET_KEY)

DEFAULT_HORIZON = int(bundle["resolved_horizon"])

HORIZON_CONFIG = {
    "short": max(1, DEFAULT_HORIZON // 2),
    "long": DEFAULT_HORIZON,
}

dataset_info = {
    "dataset_key": bundle["dataset_key"],
    "domain": bundle["domain"],
    "frequency": bundle["normalized_frequency"],
    "default_horizon": bundle["resolved_horizon"],
    "horizon_strategy": bundle["horizon_strategy"],
    "short_horizon": HORIZON_CONFIG["short"],
    "long_horizon": HORIZON_CONFIG["long"],
    "num_series": len(bundle["records_df"]),
    "num_long_rows": len(bundle["long_df"]),
}

dataset_info
# Out:
# {'dataset_key': 'fred_md',
#  'domain': 'finance',
#  'frequency': 'monthly',
#  'default_horizon': 24,
#  'horizon_strategy': 'fallback_capped',
#  'short_horizon': 12,
#  'long_horizon': 24,
#  'num_series': 107,
#  'num_long_rows': 77896}

# %%
records_df = bundle["records_df"]
first_series = records_df.iloc[0]
values = first_series["series_values"][:500]

plt.figure(figsize=(12, 4))
plt.plot(values)
plt.title(f"Sample series preview: {DATASET_KEY}")
plt.xlabel("Step")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %%
TIMESFM_DATASET_CONFIGS = {
    "fred_md": {
        "max_context": 64,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },
}

MODEL_PARAMS_BY_MODEL = {
    "timesfm": TIMESFM_DATASET_CONFIGS.get(DATASET_KEY, {}),
}

# %%
run_outputs = []

for horizon_type, horizon in HORIZON_CONFIG.items():
    print(f"\n==============================")
    print(f"Running horizon: {horizon_type} | h={horizon}")
    print(f"==============================")

    for model_name in MODELS:
        print(f"\nRunning model: {model_name}")

        model_params = MODEL_PARAMS_BY_MODEL.get(model_name, {})

        result_df = run_model_experiment(
            dataset_key=DATASET_KEY,
            model_name=model_name,
            horizon=horizon,
            horizon_type=horizon_type,
            experiment_type="baseline",
            output_dir=OUTPUT_DIR,
            model_params=model_params,
            series_limit=None,
            save_results=True,
        )

        run_outputs.append(result_df)

print("All runs completed.")
# Out:
# ==============================
# Running horizon: short | h=12
# ==============================
#
# Running model: naive
# Saved: results/raw_runs/finance/fred_md/naive_short_h12_baseline.csv
#
# Running model: seasonal_naive
# Saved: results/raw_runs/finance/fred_md/seasonal_naive_short_h12_baseline.csv
#
# Running model: arima
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Saved: results/raw_runs/finance/fred_md/arima_short_h12_baseline.csv
#
# Running model: prophet
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:p-42191:t-8713740480:forecaster.py:parse_seasonality_args:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# ...
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# Saved: results/raw_runs/finance/fred_md/ttm_long_h24_baseline.csv
#
# Running model: uni2ts
# Saved: results/raw_runs/finance/fred_md/uni2ts_long_h24_baseline.csv
# All runs completed.

# %%
combined_df = pd.concat(run_outputs, ignore_index=True)

combined_df.head()
# Out:
#   series_id dataset_key   domain frequency  model  horizon          mae  \
# 0        T1     fred_md  finance   monthly  naive       12   276.227083
# 1        T2     fred_md  finance   monthly  naive       12   192.133333
# 2        T3     fred_md  finance   monthly  naive       12     1.205917
# 3        T4     fred_md  finance   monthly  naive       12  8799.666667
# 4        T5     fred_md  finance   monthly  naive       12     0.419250
#
#            rmse     smape  fit_time_seconds  ...  \
# 0    329.202484  1.648329          0.000009  ...
# 1    228.075433  1.377981          0.000004  ...
# 2      1.524878  1.010107          0.000002  ...
# 3  11006.062852  1.719513          0.000002  ...
# 4      0.518270  0.382017          0.000002  ...
#
#    use_continuous_quantile_head  force_flip_invariance infer_is_positive  \
# 0                           NaN                    NaN               NaN
# 1                           NaN                    NaN               NaN
# 2                           NaN                    NaN               NaN
# 3                           NaN                    NaN               NaN
# 4                           NaN                    NaN               NaN
#
#   fix_quantile_crossing  model_path  normalized_frequency  \
# 0                   NaN         NaN                   NaN
# 1                   NaN         NaN                   NaN
# 2                   NaN         NaN                   NaN
# 3                   NaN         NaN                   NaN
# 4                   NaN         NaN                   NaN
#
#   prefer_longer_context prefer_l1_loss context_length num_samples
# 0                   NaN            NaN            NaN         NaN
# 1                   NaN            NaN            NaN         NaN
# 2                   NaN            NaN            NaN         NaN
# 3                   NaN            NaN            NaN         NaN
# 4                   NaN            NaN            NaN         NaN
#
# [5 rows x 55 columns]

# %%
failed_df = combined_df[combined_df["status"] != "success"].copy()

failed_df[["dataset_key", "model", "horizon_type", "series_id", "error_message"]].head(20)
# Out:
# Empty DataFrame
# Columns: [dataset_key, model, horizon_type, series_id, error_message]
# Index: []

# %%
accuracy_summary_df = (
    combined_df[combined_df["status"] == "success"]
    .groupby(["dataset_key", "frequency", "model", "horizon_type", "horizon"], as_index=False)
    .agg(
        n_series=("series_id", "count"),
        mae=("mae", "mean"),
        rmse=("rmse", "mean"),
        smape=("smape", "mean"),
    )
    .sort_values(["horizon_type", "smape"])
    .reset_index(drop=True)
)

accuracy_summary_df
# Out:
#    dataset_key frequency           model horizon_type  horizon  n_series  \
# 0      fred_md   monthly             ttm         long       24       107
# 1      fred_md   monthly         timesfm         long       24       107
# 2      fred_md   monthly           arima         long       24       107
# 3      fred_md   monthly           naive         long       24       107
# 4      fred_md   monthly  seasonal_naive         long       24       107
# 5      fred_md   monthly          uni2ts         long       24       107
# 6      fred_md   monthly         prophet         long       24       107
# 7      fred_md   monthly            lstm         long       24       107
# 8      fred_md   monthly         timesfm        short       12       107
# 9      fred_md   monthly           arima        short       12       107
# 10     fred_md   monthly             ttm        short       12       107
# 11     fred_md   monthly           naive        short       12       107
# 12     fred_md   monthly  seasonal_naive        short       12       107
# 13     fred_md   monthly          uni2ts        short       12       107
# 14     fred_md   monthly         prophet        short       12       107
# 15     fred_md   monthly            lstm        short       12       107
#
#              mae          rmse       smape
# 0    4281.675827   4936.726207   12.239916
# 1    5015.486957   5732.563643   13.074179
# 2    5859.820000   6641.992951   14.512311
# 3    5365.955689   6207.925540   14.535991
# 4    4839.166406   5588.497740   16.507916
# 5    9644.779489  10525.230882   21.466798
# 6   14099.147765  14817.779101   30.045277
# 7   46124.438934  46315.262760  147.581195
# 8    2769.741817   3203.209694   10.291124
# 9    2633.265798   2975.561807   10.498672
# 10   2473.287259   2702.658580   10.609710
# 11   2825.672457   3128.761593   10.702967
# 12   5385.529178   5578.140103   14.589711
# 13   8071.128200   8295.147879   16.655185
# 14  14645.740586  14810.925066   30.465052
# 15  44053.113831  44095.352037  143.450684

# %%
best_idx = accuracy_summary_df.groupby("horizon_type")["smape"].idxmin()

best_model_per_horizon_df = accuracy_summary_df.loc[
    best_idx,
    ["horizon_type", "horizon", "model", "smape", "mae", "rmse"]
].reset_index(drop=True)

best_model_per_horizon_df
# Out:
#   horizon_type  horizon    model      smape          mae         rmse
# 0         long       24      ttm  12.239916  4281.675827  4936.726207
# 1        short       12  timesfm  10.291124  2769.741817  3203.209694

# %%
runtime_summary_df = (
    combined_df[combined_df["status"] == "success"]
    .groupby(["model", "horizon_type", "horizon"], as_index=False)
    .agg(
        avg_fit_time_seconds=("fit_time_seconds", "mean"),
        avg_inference_time_seconds=("inference_time_seconds", "mean"),
        avg_series_total_time_seconds=("series_total_time_seconds", "mean"),
        avg_peak_memory_mb=("peak_memory_mb", "mean"),
        n_series=("series_id", "count"),
    )
    .sort_values(["horizon_type", "avg_series_total_time_seconds"])
    .reset_index(drop=True)
)

runtime_summary_df
# Out:
#              model horizon_type  horizon  avg_fit_time_seconds  \
# 0            naive         long       24              0.000001
# 1   seasonal_naive         long       24              0.000001
# 2            arima         long       24              0.000003
# 3              ttm         long       24              0.000003
# 4          timesfm         long       24              0.000028
# 5          prophet         long       24              0.000051
# 6           uni2ts         long       24              0.000007
# 7             lstm         long       24              0.000002
# 8            naive        short       12              0.000002
# 9   seasonal_naive        short       12              0.000001
# 10           arima        short       12              0.000003
# 11             ttm        short       12              0.000003
# 12         prophet        short       12              0.000033
# 13         timesfm        short       12              0.000050
# 14          uni2ts        short       12              0.000004
# 15            lstm        short       12              0.000004
#
#     avg_inference_time_seconds  avg_series_total_time_seconds  \
# 0                     0.000015                       0.000019
# 1                     0.000084                       0.000088
# 2                     0.105122                       0.105131
# 3                     0.140930                       0.140937
# 4                     0.347477                       0.347509
# 5                     0.455052                       0.455110
# 6                     1.229507                       1.229520
# 7                     1.929061                       1.929068
# 8                     0.000018                       0.000023
# 9                     0.000062                       0.000067
# 10                    0.114323                       0.114333
# 11                    0.158587                       0.158596
# 12                    0.423460                       0.423499
# 13                    0.464267                       0.464323
# 14                    1.321941                       1.321952
# 15                    2.465200                       2.465210
#
#     avg_peak_memory_mb  n_series
# 0             0.147373       107
# 1             0.156796       107
# 2             5.393567       107
# 3             1.194079       107
# 4             0.219497       107
# 5            24.052765       107
# 6             1.816807       107
# 7             0.588050       107
# 8             0.147395       107
# 9             0.152084       107
# 10            6.984504       107
# 11            1.237462       107
# 12           25.339593       107
# 13           12.223548       107
# 14            2.378220       107
# 15            0.579212       107

# %%
horizon_comparison_df = accuracy_summary_df.pivot_table(
    index="model",
    columns="horizon_type",
    values="smape",
    aggfunc="mean",
).reset_index()

horizon_comparison_df["smape_change_long_minus_short"] = (
    horizon_comparison_df["long"] - horizon_comparison_df["short"]
)

horizon_comparison_df = horizon_comparison_df.sort_values("long").reset_index(drop=True)

horizon_comparison_df
# Out:
# horizon_type           model        long       short  \
# 0                        ttm   12.239916   10.609710
# 1                    timesfm   13.074179   10.291124
# 2                      arima   14.512311   10.498672
# 3                      naive   14.535991   10.702967
# 4             seasonal_naive   16.507916   14.589711
# 5                     uni2ts   21.466798   16.655185
# 6                    prophet   30.045277   30.465052
# 7                       lstm  147.581195  143.450684
#
# horizon_type  smape_change_long_minus_short
# 0                                  1.630206
# 1                                  2.783055
# 2                                  4.013639
# 3                                  3.833024
# 4                                  1.918205
# 5                                  4.811613
# 6                                 -0.419775
# 7                                  4.130511

# %%
def map_model_family(model_name: str) -> str:
    if model_name in {"naive", "seasonal_naive", "arima", "prophet", "lstm"}:
        return "traditional"
    if model_name in {"timesfm", "ttm", "uni2ts"}:
        return "foundation"
    return "other"


accuracy_summary_df["model_family"] = accuracy_summary_df["model"].apply(map_model_family)
runtime_summary_df["model_family"] = runtime_summary_df["model"].apply(map_model_family)

accuracy_summary_df.head()
# Out:
#   dataset_key frequency           model horizon_type  horizon  n_series  \
# 0     fred_md   monthly             ttm         long       24       107
# 1     fred_md   monthly         timesfm         long       24       107
# 2     fred_md   monthly           arima         long       24       107
# 3     fred_md   monthly           naive         long       24       107
# 4     fred_md   monthly  seasonal_naive         long       24       107
#
#            mae         rmse      smape model_family
# 0  4281.675827  4936.726207  12.239916   foundation
# 1  5015.486957  5732.563643  13.074179   foundation
# 2  5859.820000  6641.992951  14.512311  traditional
# 3  5365.955689  6207.925540  14.535991  traditional
# 4  4839.166406  5588.497740  16.507916  traditional

# %%
family_accuracy_df = (
    accuracy_summary_df
    .groupby(["model_family", "horizon_type"], as_index=False)
    .agg(
        avg_mae=("mae", "mean"),
        avg_rmse=("rmse", "mean"),
        avg_smape=("smape", "mean"),
    )
    .sort_values(["horizon_type", "avg_smape"])
    .reset_index(drop=True)
)

family_accuracy_df
# Out:
#   model_family horizon_type       avg_mae      avg_rmse  avg_smape
# 0   foundation         long   6313.980758   7064.840244  15.593631
# 1  traditional         long  15257.705759  15914.291619  44.636538
# 2   foundation        short   4438.052426   4733.672051  12.518673
# 3  traditional        short  13908.664370  14117.748121  41.941417

# %%
family_runtime_df = (
    runtime_summary_df
    .groupby(["model_family", "horizon_type"], as_index=False)
    .agg(
        avg_fit_time_seconds=("avg_fit_time_seconds", "mean"),
        avg_inference_time_seconds=("avg_inference_time_seconds", "mean"),
        avg_series_total_time_seconds=("avg_series_total_time_seconds", "mean"),
        avg_peak_memory_mb=("avg_peak_memory_mb", "mean"),
    )
    .sort_values(["horizon_type", "avg_series_total_time_seconds"])
    .reset_index(drop=True)
)

family_runtime_df
# Out:
#   model_family horizon_type  avg_fit_time_seconds  avg_inference_time_seconds  \
# 0  traditional         long              0.000012                    0.497867
# 1   foundation         long              0.000012                    0.572638
# 2  traditional        short              0.000009                    0.600613
# 3   foundation        short              0.000019                    0.648265
#
#    avg_series_total_time_seconds  avg_peak_memory_mb
# 0                       0.497883            6.067710
# 1                       0.572656            1.076794
# 2                       0.600627            6.640558
# 3                       0.648290            5.279743

# %%
for horizon_type in HORIZON_CONFIG.keys():
    subset = accuracy_summary_df[accuracy_summary_df["horizon_type"] == horizon_type].copy()
    subset = subset.sort_values("smape")

    plt.figure(figsize=(10, 4))
    plt.bar(subset["model"], subset["smape"])
    plt.title(f"{DATASET_KEY}: Model Accuracy ({horizon_type} horizon)")
    plt.xlabel("Model")
    plt.ylabel("sMAPE")
    plt.xticks(rotation=45)
    plt.grid(axis="y")
    plt.show()

# %%
plot_df = accuracy_summary_df.copy()

plt.figure(figsize=(10, 5))

for model_name in plot_df["model"].unique():
    subset = plot_df[plot_df["model"] == model_name].sort_values("horizon")
    plt.plot(subset["horizon"], subset["smape"], marker="o", label=model_name)

plt.title(f"{DATASET_KEY}: Accuracy vs Horizon Length")
plt.xlabel("Horizon Length")
plt.ylabel("sMAPE")
plt.legend()
plt.grid(True)
plt.show()

# %%
runtime_plot_df = (
    runtime_summary_df
    .groupby("model", as_index=False)["avg_inference_time_seconds"]
    .mean()
    .sort_values("avg_inference_time_seconds")
)

plt.figure(figsize=(10, 4))
plt.bar(runtime_plot_df["model"], runtime_plot_df["avg_inference_time_seconds"])
plt.title(f"{DATASET_KEY}: Average Inference Time by Model")
plt.xlabel("Model")
plt.ylabel("Average inference time per series (seconds)")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
final_dir = Path("results/aggregated")
final_dir.mkdir(parents=True, exist_ok=True)

accuracy_summary_df.to_csv(final_dir / f"{DATASET_KEY}_accuracy_summary.csv", index=False)
best_model_per_horizon_df.to_csv(final_dir / f"{DATASET_KEY}_best_model_per_horizon.csv", index=False)
runtime_summary_df.to_csv(final_dir / f"{DATASET_KEY}_runtime_summary.csv", index=False)
horizon_comparison_df.to_csv(final_dir / f"{DATASET_KEY}_horizon_comparison.csv", index=False)
family_accuracy_df.to_csv(final_dir / f"{DATASET_KEY}_family_accuracy.csv", index=False)
family_runtime_df.to_csv(final_dir / f"{DATASET_KEY}_family_runtime.csv", index=False)

print("Saved outputs to:", final_dir)
# Out:
# Saved outputs to: results/aggregated

# %%
TIMESFM_TEST_CONFIGS = [
    # very safe (prevents NaNs)
    {
        "max_context": 16,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    # standard stable
    {
        "max_context": 32,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    # usually best balance
    {
        "max_context": 64,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    # higher context (may break)
    {
        "max_context": 128,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    # normalization OFF (important test for FRED)
    {
        "max_context": 32,
        "max_horizon": 256,
        "normalize_inputs": False,
        "use_continuous_quantile_head": True,
        "force_flip_invariance": False,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    {
        "max_context": 64,
        "max_horizon": 256,
        "normalize_inputs": False,
        "use_continuous_quantile_head": True,
        "force_flip_invariance": False,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },
]

# %%
timesfm_config_results_long = []

for i, params in enumerate(TIMESFM_TEST_CONFIGS, start=1):
    print(f"\n==============================")
    print(f"Testing TimesFM config {i} — long horizon")
    print(params)
    print("==============================")

    test_df = run_model_experiment(
        dataset_key="fred_md",
        model_name="timesfm",
        horizon=HORIZON_CONFIG["long"],
        horizon_type="long",
        experiment_type=f"timesfm_config_test_long_{i}",
        output_dir=OUTPUT_DIR,
        model_params=params,
        series_limit=10,
        save_results=False,
    )

    display(test_df[["series_id", "status", "error_message", "mae", "rmse", "smape"]])
    print(test_df["status"].value_counts())

    timesfm_config_results_long.append(test_df)
# Out:
# ==============================
# Testing TimesFM config 1 — long horizon
# {'max_context': 16, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:compile:When compiling, max context needs to be multiple of the patch size 32. Using max context = 32 instead.
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    353.250008    408.182248  2.138766
# 1        T2  success          None    321.622762    381.103336  2.344648
# 2        T3  success          None      2.981732      3.297726  2.546533
# 3        T4  success          None  29517.263021  31792.205187  6.002159
# 4        T5  success          None      4.780128      5.213749  4.497626
# 5        T6  success          None      3.176861      3.342529  3.085946
# 6        T7  success          None      3.230700      3.396812  3.177526
# 7        T8  success          None      2.058980      2.214013  1.961043
# 8        T9  success          None      2.519843      2.969111  2.090447
# 9       T10  success          None      1.883893      2.052629  1.861736
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 2 — long horizon
# {'max_context': 32, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    241.055224    264.375039  1.455938
# 1        T2  success          None    228.934294    263.681908  1.662071
# 2        T3  success          None      1.415900      1.520037  1.201673
# 3        T4  success          None  21346.363281  22940.361449  4.300280
# 4        T5  success          None      3.258173      3.563971  3.039867
# 5        T6  success          None      2.288478      2.457900  2.212068
# 6        T7  success          None      2.273981      2.465754  2.224447
# 7        T8  success          None      2.233246      2.381293  2.129048
# 8        T9  success          None      2.940085      3.376689  2.444937
# 9       T10  success          None      1.935707      2.085177  1.913386
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 3 — long horizon
# {'max_context': 64, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    453.854744    532.926839  2.758520
# 1        T2  success          None    416.499430    475.083111  3.050212
# 2        T3  success          None      2.007982      2.172409  1.707364
# 3        T4  success          None  20609.062500  21726.801382  4.150082
# 4        T5  success          None      3.994666      4.354125  3.742284
# 5        T6  success          None      2.659816      2.860358  2.576724
# 6        T7  success          None      2.263551      2.426137  2.214479
# 7        T8  success          None      1.862381      2.024164  1.771879
# 8        T9  success          None      2.236367      2.630734  1.852419
# 9       T10  success          None      2.066285      2.213887  2.043988
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 4 — long horizon
# {'max_context': 128, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    412.010262    479.036987  2.500212
# 1        T2  success          None    240.789876    272.581387  1.749570
# 2        T3  success          None      2.742113      3.004746  2.339280
# 3        T4  success          None  20272.940104  21556.211015  4.080412
# 4        T5  success          None      3.984419      4.324300  3.732601
# 5        T6  success          None      0.625208      0.728720  0.598824
# 6        T7  success          None      0.937997      1.088999  0.910691
# 7        T8  success          None      1.534170      1.714021  1.456927
# 8        T9  success          None      2.357732      2.765684  1.954516
# 9       T10  success          None      1.649132      1.809039  1.627414
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 5 — long horizon
# {'max_context': 32, 'max_horizon': 256, 'normalize_inputs': False, 'use_continuous_quantile_head': True, 'force_flip_invariance': False, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    160.951527    180.122902  0.973149
# 1        T2  success          None     80.016113     97.621953  0.577914
# 2        T3  success          None      1.114348      1.193303  0.945793
# 3        T4  success          None  26340.875000  28048.454293  5.336890
# 4        T5  success          None      3.134491      3.445866  2.922397
# 5        T6  success          None      2.296857      2.468572  2.220303
# 6        T7  success          None      2.414435      2.605857  2.363736
# 7        T8  success          None      2.201126      2.351017  2.098061
# 8        T9  success          None      2.817621      3.252720  2.341465
# 9       T10  success          None      1.962507      2.111523  1.940175
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 6 — long horizon
# {'max_context': 64, 'max_horizon': 256, 'normalize_inputs': False, 'use_continuous_quantile_head': True, 'force_flip_invariance': False, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message           mae          rmse     smape
# 0        T1  success          None    424.032804    497.624840  2.574110
# 1        T2  success          None    387.317790    439.952598  2.832708
# 2        T3  success          None      1.785729      1.933688  1.516879
# 3        T4  success          None  19418.325521  20455.953313  3.905698
# 4        T5  success          None      3.957157      4.299284  3.706376
# 5        T6  success          None      2.662825      2.920419  2.580602
# 6        T7  success          None      2.202640      2.364671  2.154193
# 7        T8  success          None      1.836643      2.002871  1.747154
# 8        T9  success          None      2.439999      2.909283  2.023369
# 9       T10  success          None      2.062156      2.211239  2.039857
# status
# success    10
# Name: count, dtype: int64

# %%
timesfm_config_results_short = []

for i, params in enumerate(TIMESFM_TEST_CONFIGS, start=1):
    print(f"\n==============================")
    print(f"Testing TimesFM config {i} — short horizon")
    print(params)
    print("==============================")

    test_df = run_model_experiment(
        dataset_key="fred_md",
        model_name="timesfm",
        horizon=HORIZON_CONFIG["short"],
        horizon_type="short",
        experiment_type=f"timesfm_config_test_short_{i}",
        output_dir=OUTPUT_DIR,
        model_params=params,
        series_limit=10,
        save_results=False,
    )

    display(test_df[["series_id", "status", "error_message", "mae", "rmse", "smape"]])
    print(test_df["status"].value_counts())

    timesfm_config_results_short.append(test_df)
# Out:
# ==============================
# Testing TimesFM config 1 — short horizon
# {'max_context': 16, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:compile:When compiling, max context needs to be multiple of the patch size 32. Using max context = 32 instead.
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None    56.440258    67.094231  0.335715
# 1        T2  success          None    50.276872    60.429611  0.359898
# 2        T3  success          None     0.670472     0.816563  0.560862
# 3        T4  success          None  6990.205729  8659.825966  1.362745
# 4        T5  success          None     0.567606     0.745699  0.517901
# 5        T6  success          None     0.854281     0.921820  0.815792
# 6        T7  success          None     1.078953     1.161538  1.043145
# 7        T8  success          None     0.628074     0.748077  0.592733
# 8        T9  success          None     1.708955     1.942859  1.406207
# 9       T10  success          None     0.477572     0.647064  0.467532
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 2 — short horizon
# {'max_context': 32, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None   147.890191   165.452064  0.878673
# 1        T2  success          None    55.841846    70.745442  0.400258
# 2        T3  success          None     0.477562     0.625757  0.399208
# 3        T4  success          None  4363.447917  5483.018731  0.852801
# 4        T5  success          None     1.165529     1.394747  1.056883
# 5        T6  success          None     0.418642     0.523698  0.398940
# 6        T7  success          None     0.596955     0.695099  0.575512
# 7        T8  success          None     0.585718     0.742313  0.552618
# 8        T9  success          None     1.752582     1.986957  1.441970
# 9       T10  success          None     0.510407     0.696896  0.499690
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 3 — short horizon
# {'max_context': 64, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None   105.440647   116.874185  0.625561
# 1        T2  success          None    39.481706    47.243122  0.282582
# 2        T3  success          None     0.775613     0.895867  0.646302
# 3        T4  success          None  4323.213542  5685.317353  0.843512
# 4        T5  success          None     0.997525     1.257658  0.905135
# 5        T6  success          None     0.530497     0.619762  0.505765
# 6        T7  success          None     0.931865     1.025374  0.900345
# 7        T8  success          None     0.631852     0.774956  0.596178
# 8        T9  success          None     1.614021     2.058406  1.328105
# 9       T10  success          None     0.590421     0.756601  0.578245
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 4 — short horizon
# {'max_context': 128, 'max_horizon': 256, 'normalize_inputs': True, 'use_continuous_quantile_head': True, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None    86.430452    93.038699  0.513746
# 1        T2  success          None    52.571436    60.368504  0.376229
# 2        T3  success          None     0.913469     1.019025  0.760289
# 3        T4  success          None  5488.520833  6544.542318  1.068939
# 4        T5  success          None     0.631485     0.767084  0.574626
# 5        T6  success          None     0.558902     0.693390  0.532221
# 6        T7  success          None     0.494525     0.637624  0.476540
# 7        T8  success          None     0.705064     0.836766  0.665152
# 8        T9  success          None     1.670552     2.118526  1.374214
# 9       T10  success          None     0.726457     0.844638  0.711141
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 5 — short horizon
# {'max_context': 32, 'max_horizon': 256, 'normalize_inputs': False, 'use_continuous_quantile_head': True, 'force_flip_invariance': False, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None   176.583388   196.995912  1.049961
# 1        T2  success          None    67.119059    86.998486  0.480886
# 2        T3  success          None     0.587081     0.719655  0.489910
# 3        T4  success          None  6175.973958  6983.723111  1.204251
# 4        T5  success          None     0.942845     1.157111  0.856038
# 5        T6  success          None     0.506649     0.597028  0.482875
# 6        T7  success          None     0.602737     0.709287  0.581071
# 7        T8  success          None     0.593122     0.733023  0.559605
# 8        T9  success          None     1.864537     2.074483  1.534229
# 9       T10  success          None     0.518641     0.710499  0.507730
# status
# success    10
# Name: count, dtype: int64
#
# ==============================
# Testing TimesFM config 6 — short horizon
# {'max_context': 64, 'max_horizon': 256, 'normalize_inputs': False, 'use_continuous_quantile_head': True, 'force_flip_invariance': False, 'infer_is_positive': True, 'fix_quantile_crossing': True}
# ==============================
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
#   series_id   status error_message          mae         rmse     smape
# 0        T1  success          None    95.203831   105.936772  0.564784
# 1        T2  success          None    31.553760    43.453826  0.226041
# 2        T3  success          None     0.984639     1.085879  0.820008
# 3        T4  success          None  4738.145833  6131.541593  0.923511
# 4        T5  success          None     1.138617     1.353079  1.032531
# 5        T6  success          None     0.576252     0.658157  0.549618
# 6        T7  success          None     0.924076     1.025006  0.892964
# 7        T8  success          None     0.664706     0.806148  0.627161
# 8        T9  success          None     1.556695     2.023526  1.281174
# 9       T10  success          None     0.589082     0.763688  0.576983
# status
# success    10
# Name: count, dtype: int64

# %% [markdown]
# ## Initial Findings
#
# This single-dataset experiment evaluates all traditional, deep learning, and foundation models on both short and long forecasting horizons.
#
# Key points to inspect:
# - Which model has the lowest sMAPE for the short horizon?
# - Which model has the lowest sMAPE for the long horizon?
# - Does model ranking change as horizon length increases?
# - Do foundation models improve or degrade more slowly than traditional models?
# - Which models are fastest at inference?
# - Which models have the highest memory usage?
#
# This notebook validates the final experiment structure before scaling to all datasets on HPC.

# %%
baseline_accuracy_df = accuracy_summary_df.copy()
baseline_runtime_df = runtime_summary_df.copy()

print("Baseline saved.")
# Out:
# Baseline saved.

# %%
TUNED_MODEL_PARAMS = {
    "timesfm": {
        "max_context": 64,
        "max_horizon": 256,
        "normalize_inputs": True,
        "use_continuous_quantile_head": True,
        "infer_is_positive": True,
        "fix_quantile_crossing": True,
    },

    "ttm": {
        "max_context": 512,
        "prefer_l1_loss": True,
    },

    "arima": {
        "order": (2, 1, 2),
    },

    "prophet": {
        "yearly_seasonality": True,
        "weekly_seasonality": False,
        "daily_seasonality": False,
        "changepoint_prior_scale": 0.03,
        "seasonality_prior_scale": 10.0,
        "seasonality_mode": "additive",
    },

    "lstm": {
        "hidden_size": 128,
        "num_layers": 2,
        "epochs": 50,
        "learning_rate": 0.0005,
    },

    "uni2ts": {},

    "naive": {},
    "seasonal_naive": {},
}

# %%
run_outputs_tuned = []

for horizon_type, horizon in HORIZON_CONFIG.items():
    print(f"\n==============================")
    print(f"TUNED → horizon: {horizon_type} | h={horizon}")
    print(f"==============================")

    for model_name in MODELS:
        print(f"\nRunning tuned model: {model_name}")

        result_df = run_model_experiment(
            dataset_key=DATASET_KEY,
            model_name=model_name,
            horizon=horizon,
            horizon_type=horizon_type,
            experiment_type="tuned",
            output_dir=OUTPUT_DIR,
            model_params=TUNED_MODEL_PARAMS.get(model_name, {}),
            series_limit=None,
            save_results=True,
        )

        run_outputs_tuned.append(result_df)

print("All tuned runs completed.")
# Out:
# ==============================
# TUNED → horizon: short | h=12
# ==============================
#
# Running tuned model: naive
# Saved: results/raw_runs/finance/fred_md/naive_short_h12_tuned.csv
#
# Running tuned model: seasonal_naive
# Saved: results/raw_runs/finance/fred_md/seasonal_naive_short_h12_tuned.csv
#
# Running tuned model: arima
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Saved: results/raw_runs/finance/fred_md/arima_short_h12_tuned.csv
#
# Running tuned model: prophet
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# Saved: results/raw_runs/finance/fred_md/prophet_short_h12_tuned.csv
#
# Running tuned model: lstm
# Saved: results/raw_runs/finance/fred_md/lstm_short_h12_tuned.csv
#
# Running tuned model: timesfm
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from local directory: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3
# INFO:p-42191:t-8713740480:timesfm_2p5_torch.py:_from_pretrained:Loading checkpoint from: /Users/kunalgurung/.cache/huggingface/hub/models--google--timesfm-2.5-200m-pytorch/snapshots/1d952420fba87f3c6dee4f240de0f1a0fbc790e3/model.safetensors
# Compiling model...
# Saved: results/raw_runs/finance/fred_md/timesfm_short_h12_tuned.csv
#
# Running tuned model: ttm
# INFO:p-42191:t-8713740480:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# WARNING:p-42191:t-8713740480:get_model.py:get_model:Requested `prediction_length` (12) is not exactly equal to any of the available TTM prediction lengths. Hence, TTM will forecast using the `prediction_filter_length` argument to provide the requested prediction length. Check the model card to know more about the supported context lengths and forecast/prediction lengths.
# INFO:p-42191:t-8713740480:get_model.py:get_model:Model loaded successfully from ibm-granite/granite-timeseries-ttm-r2, revision = 512-48-ft-l1-r2.1.
# INFO:p-42191:t-8713740480:get_model.py:get_model:[TTM] context_length = 512, prediction_length = 48
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# Saved: results/raw_runs/finance/fred_md/ttm_short_h12_tuned.csv
#
# Running tuned model: uni2ts
# Saved: results/raw_runs/finance/fred_md/uni2ts_short_h12_tuned.csv
#
# ==============================
# TUNED → horizon: long | h=24
# ==============================
#
# Running tuned model: naive
# Saved: results/raw_runs/finance/fred_md/naive_long_h24_tuned.csv
#
# Running tuned model: seasonal_naive
# Saved: results/raw_runs/finance/fred_md/seasonal_naive_long_h24_tuned.csv
#
# Running tuned model: arima
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/kunalgurung/Desktop/UTS SEM4/36127/foundation-models-timeseries-forecasting-pile-ghanti/.venv/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Saved: results/raw_runs/finance/fred_md/arima_long_h24_tuned.csv
#
# Running tuned model: prophet
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] start processing
# INFO:p-42191:t-8713740480:model.py:_run_cmdstan:Chain [1] done processing
# ...
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# WARNING:p-42191:t-8713740480:time_series_preprocessor.py:get_frequency_token:Frequency token M was not found in the frequency token mapping.
# Device set to use cpu
# Saved: results/raw_runs/finance/fred_md/ttm_long_h24_tuned.csv
#
# Running tuned model: uni2ts
# Saved: results/raw_runs/finance/fred_md/uni2ts_long_h24_tuned.csv
# All tuned runs completed.

# %%
combined_tuned_df = pd.concat(run_outputs_tuned, ignore_index=True)

combined_tuned_df.head()
# Out:
#   series_id dataset_key   domain frequency  model  horizon          mae  \
# 0        T1     fred_md  finance   monthly  naive       12   276.227083
# 1        T2     fred_md  finance   monthly  naive       12   192.133333
# 2        T3     fred_md  finance   monthly  naive       12     1.205917
# 3        T4     fred_md  finance   monthly  naive       12  8799.666667
# 4        T5     fred_md  finance   monthly  naive       12     0.419250
#
#            rmse     smape  fit_time_seconds  ...  \
# 0    329.202484  1.648329      3.099442e-06  ...
# 1    228.075433  1.377981      9.536743e-07  ...
# 2      1.524878  1.010107      2.145767e-06  ...
# 3  11006.062852  1.719513      9.536743e-07  ...
# 4      0.518270  0.382017      9.536743e-07  ...
#
#    use_continuous_quantile_head  force_flip_invariance infer_is_positive  \
# 0                           NaN                    NaN               NaN
# 1                           NaN                    NaN               NaN
# 2                           NaN                    NaN               NaN
# 3                           NaN                    NaN               NaN
# 4                           NaN                    NaN               NaN
#
#   fix_quantile_crossing  model_path  normalized_frequency  \
# 0                   NaN         NaN                   NaN
# 1                   NaN         NaN                   NaN
# 2                   NaN         NaN                   NaN
# 3                   NaN         NaN                   NaN
# 4                   NaN         NaN                   NaN
#
#   prefer_longer_context prefer_l1_loss context_length num_samples
# 0                   NaN            NaN            NaN         NaN
# 1                   NaN            NaN            NaN         NaN
# 2                   NaN            NaN            NaN         NaN
# 3                   NaN            NaN            NaN         NaN
# 4                   NaN            NaN            NaN         NaN
#
# [5 rows x 55 columns]

# %%
accuracy_tuned_df = (
    combined_tuned_df[combined_tuned_df["status"] == "success"]
    .groupby(["dataset_key", "frequency", "model", "horizon_type", "horizon"], as_index=False)
    .agg(
        n_series=("series_id", "count"),
        mae=("mae", "mean"),
        rmse=("rmse", "mean"),
        smape=("smape", "mean"),
    )
    .sort_values(["horizon_type", "smape"])
    .reset_index(drop=True)
)

accuracy_tuned_df
# Out:
#    dataset_key frequency           model horizon_type  horizon  n_series  \
# 0      fred_md   monthly         timesfm         long       24       107
# 1      fred_md   monthly             ttm         long       24       107
# 2      fred_md   monthly           arima         long       24       107
# 3      fred_md   monthly           naive         long       24       107
# 4      fred_md   monthly  seasonal_naive         long       24       107
# 5      fred_md   monthly          uni2ts         long       24       107
# 6      fred_md   monthly         prophet         long       24       107
# 7      fred_md   monthly            lstm         long       24       107
# 8      fred_md   monthly         timesfm        short       12       107
# 9      fred_md   monthly             ttm        short       12       107
# 10     fred_md   monthly           arima        short       12       107
# 11     fred_md   monthly           naive        short       12       107
# 12     fred_md   monthly  seasonal_naive        short       12       107
# 13     fred_md   monthly          uni2ts        short       12       107
# 14     fred_md   monthly         prophet        short       12       107
# 15     fred_md   monthly            lstm        short       12       107
#
#              mae          rmse       smape
# 0    5015.486957   5732.563643   13.074179
# 1    4661.474655   5557.212137   14.034569
# 2    5962.538464   6797.634103   14.321032
# 3    5365.955689   6207.925540   14.535991
# 4    4839.166406   5588.497740   16.507916
# 5    9235.136548  10014.896394   21.280389
# 6   11132.632177  12084.750419   29.863387
# 7   46084.729862  46275.632099  113.950581
# 8    2769.741817   3203.209694   10.291124
# 9    2177.061357   2508.868254   10.376624
# 10   1964.683650   2222.966168   10.517672
# 11   2825.672457   3128.761593   10.702967
# 12   5385.529178   5578.140103   14.589711
# 13   8108.467297   8335.061094   17.033744
# 14  11322.587442  11594.081525   26.738139
# 15  44011.607437  44053.919658  110.757233

# %%
compare_df = baseline_accuracy_df.merge(
    accuracy_tuned_df,
    on=["model", "horizon_type"],
    suffixes=("_baseline", "_tuned"),
)

compare_df["smape_improvement"] = (
    compare_df["smape_baseline"] - compare_df["smape_tuned"]
)

compare_df = compare_df.sort_values(
    ["horizon_type", "smape_improvement"],
    ascending=[True, False]
)

compare_df
# Out:
#    dataset_key_baseline frequency_baseline           model horizon_type  \
# 7               fred_md            monthly            lstm         long
# 2               fred_md            monthly           arima         long
# 5               fred_md            monthly          uni2ts         long
# 6               fred_md            monthly         prophet         long
# 1               fred_md            monthly         timesfm         long
# 3               fred_md            monthly           naive         long
# 4               fred_md            monthly  seasonal_naive         long
# 0               fred_md            monthly             ttm         long
# 15              fred_md            monthly            lstm        short
# 14              fred_md            monthly         prophet        short
# 10              fred_md            monthly             ttm        short
# 8               fred_md            monthly         timesfm        short
# 11              fred_md            monthly           naive        short
# 12              fred_md            monthly  seasonal_naive        short
# 9               fred_md            monthly           arima        short
# 13              fred_md            monthly          uni2ts        short
#
#     horizon_baseline  n_series_baseline  mae_baseline  rmse_baseline  \
# 7                 24                107  46124.438934   46315.262760
# 2                 24                107   5859.820000    6641.992951
# 5                 24                107   9644.779489   10525.230882
# 6                 24                107  14099.147765   14817.779101
# 1                 24                107   5015.486957    5732.563643
# 3                 24                107   5365.955689    6207.925540
# 4                 24                107   4839.166406    5588.497740
# 0                 24                107   4281.675827    4936.726207
# 15                12                107  44053.113831   44095.352037
# 14                12                107  14645.740586   14810.925066
# 10                12                107   2473.287259    2702.658580
# 8                 12                107   2769.741817    3203.209694
# 11                12                107   2825.672457    3128.761593
# 12                12                107   5385.529178    5578.140103
# 9                 12                107   2633.265798    2975.561807
# 13                12                107   8071.128200    8295.147879
#
#     smape_baseline model_family dataset_key_tuned frequency_tuned  \
# 7       147.581195  traditional           fred_md         monthly
# 2        14.512311  traditional           fred_md         monthly
# 5        21.466798   foundation           fred_md         monthly
# 6        30.045277  traditional           fred_md         monthly
# 1        13.074179   foundation           fred_md         monthly
# 3        14.535991  traditional           fred_md         monthly
# 4        16.507916  traditional           fred_md         monthly
# 0        12.239916   foundation           fred_md         monthly
# 15      143.450684  traditional           fred_md         monthly
# 14       30.465052  traditional           fred_md         monthly
# 10       10.609710   foundation           fred_md         monthly
# 8        10.291124   foundation           fred_md         monthly
# 11       10.702967  traditional           fred_md         monthly
# 12       14.589711  traditional           fred_md         monthly
# 9        10.498672  traditional           fred_md         monthly
# 13       16.655185   foundation           fred_md         monthly
#
#     horizon_tuned  n_series_tuned     mae_tuned    rmse_tuned  smape_tuned  \
# 7              24             107  46084.729862  46275.632099   113.950581
# 2              24             107   5962.538464   6797.634103    14.321032
# 5              24             107   9235.136548  10014.896394    21.280389
# 6              24             107  11132.632177  12084.750419    29.863387
# 1              24             107   5015.486957   5732.563643    13.074179
# 3              24             107   5365.955689   6207.925540    14.535991
# 4              24             107   4839.166406   5588.497740    16.507916
# 0              24             107   4661.474655   5557.212137    14.034569
# 15             12             107  44011.607437  44053.919658   110.757233
# 14             12             107  11322.587442  11594.081525    26.738139
# 10             12             107   2177.061357   2508.868254    10.376624
# 8              12             107   2769.741817   3203.209694    10.291124
# 11             12             107   2825.672457   3128.761593    10.702967
# 12             12             107   5385.529178   5578.140103    14.589711
# 9              12             107   1964.683650   2222.966168    10.517672
# 13             12             107   8108.467297   8335.061094    17.033744
#
#     smape_improvement
# 7           33.630614
# 2            0.191279
# 5            0.186409
# 6            0.181890
# 1            0.000000
# 3            0.000000
# 4            0.000000
# 0           -1.794653
# 15          32.693451
# 14           3.726913
# 10           0.233086
# 8            0.000000
# 11           0.000000
# 12           0.000000
# 9           -0.019000
# 13          -0.378560

# %%
runtime_tuned_df = (
    combined_tuned_df[combined_tuned_df["status"] == "success"]
    .groupby(["model", "horizon_type", "horizon"], as_index=False)
    .agg(
        avg_fit_time_seconds=("fit_time_seconds", "mean"),
        avg_inference_time_seconds=("inference_time_seconds", "mean"),
        avg_series_total_time_seconds=("series_total_time_seconds", "mean"),
        avg_peak_memory_mb=("peak_memory_mb", "mean"),
        n_series=("series_id", "count"),
    )
    .sort_values(["horizon_type", "avg_series_total_time_seconds"])
    .reset_index(drop=True)
)

runtime_tuned_df
# Out:
#              model horizon_type  horizon  avg_fit_time_seconds  \
# 0            naive         long       24          6.060734e-07
# 1   seasonal_naive         long       24          5.971606e-07
# 2              ttm         long       24          2.312883e-06
# 3            arima         long       24          1.644420e-06
# 4          prophet         long       24          5.964030e-05
# 5          timesfm         long       24          4.537306e-05
# 6           uni2ts         long       24          2.789720e-06
# 7             lstm         long       24          7.359781e-06
# 8            naive        short       12          1.174267e-06
# 9   seasonal_naive        short       12          1.002695e-06
# 10             ttm        short       12          2.393099e-06
# 11           arima        short       12          2.484455e-06
# 12         timesfm        short       12          4.887581e-05
# 13         prophet        short       12          4.354370e-05
# 14          uni2ts        short       12          3.353458e-06
# 15            lstm        short       12          1.205685e-05
#
#     avg_inference_time_seconds  avg_series_total_time_seconds  \
# 0                     0.000008                       0.000010
# 1                     0.000045                       0.000047
# 2                     0.127728                       0.127735
# 3                     0.232222                       0.232227
# 4                     0.510298                       0.510364
# 5                     0.560590                       0.560641
# 6                     1.057493                       1.057500
# 7                    26.116691                      26.116711
# 8                     0.000012                       0.000016
# 9                     0.000041                       0.000044
# 10                    0.141292                       0.141299
# 11                    0.326988                       0.326995
# 12                    0.425304                       0.425359
# 13                    0.695302                       0.695351
# 14                    1.089793                       1.089801
# 15                   29.544604                      29.544629
#
#     avg_peak_memory_mb  n_series
# 0             0.147160       107
# 1             0.156635       107
# 2             1.204708       107
# 3            11.481708       107
# 4            24.097406       107
# 5             0.224347       107
# 6             2.203263       107
# 7             0.579781       107
# 8            45.713576       107
# 9             0.150764       107
# 10            1.198418       107
# 11           11.642643       107
# 12            1.060580       107
# 13           23.614329       107
# 14            2.204543       107
# 15            0.564061       107

# %%
runtime_compare_df = baseline_runtime_df.merge(
    runtime_tuned_df,
    on=["model", "horizon_type", "horizon"],
    suffixes=("_baseline", "_tuned"),
)

runtime_compare_df["inference_time_change"] = (
    runtime_compare_df["avg_inference_time_seconds_tuned"]
    - runtime_compare_df["avg_inference_time_seconds_baseline"]
)

runtime_compare_df["memory_change_mb"] = (
    runtime_compare_df["avg_peak_memory_mb_tuned"]
    - runtime_compare_df["avg_peak_memory_mb_baseline"]
)

runtime_compare_df
# Out:
#              model horizon_type  horizon  avg_fit_time_seconds_baseline  \
# 0            naive         long       24                       0.000001
# 1   seasonal_naive         long       24                       0.000001
# 2            arima         long       24                       0.000003
# 3              ttm         long       24                       0.000003
# 4          timesfm         long       24                       0.000028
# 5          prophet         long       24                       0.000051
# 6           uni2ts         long       24                       0.000007
# 7             lstm         long       24                       0.000002
# 8            naive        short       12                       0.000002
# 9   seasonal_naive        short       12                       0.000001
# 10           arima        short       12                       0.000003
# 11             ttm        short       12                       0.000003
# 12         prophet        short       12                       0.000033
# 13         timesfm        short       12                       0.000050
# 14          uni2ts        short       12                       0.000004
# 15            lstm        short       12                       0.000004
#
#     avg_inference_time_seconds_baseline  \
# 0                              0.000015
# 1                              0.000084
# 2                              0.105122
# 3                              0.140930
# 4                              0.347477
# 5                              0.455052
# 6                              1.229507
# 7                              1.929061
# 8                              0.000018
# 9                              0.000062
# 10                             0.114323
# 11                             0.158587
# 12                             0.423460
# 13                             0.464267
# 14                             1.321941
# 15                             2.465200
#
#     avg_series_total_time_seconds_baseline  avg_peak_memory_mb_baseline  \
# 0                                 0.000019                     0.147373
# 1                                 0.000088                     0.156796
# 2                                 0.105131                     5.393567
# 3                                 0.140937                     1.194079
# 4                                 0.347509                     0.219497
# 5                                 0.455110                    24.052765
# 6                                 1.229520                     1.816807
# 7                                 1.929068                     0.588050
# 8                                 0.000023                     0.147395
# 9                                 0.000067                     0.152084
# 10                                0.114333                     6.984504
# 11                                0.158596                     1.237462
# 12                                0.423499                    25.339593
# 13                                0.464323                    12.223548
# 14                                1.321952                     2.378220
# 15                                2.465210                     0.579212
#
#     n_series_baseline model_family  avg_fit_time_seconds_tuned  \
# 0                 107  traditional                6.060734e-07
# 1                 107  traditional                5.971606e-07
# 2                 107  traditional                1.644420e-06
# 3                 107   foundation                2.312883e-06
# 4                 107   foundation                4.537306e-05
# 5                 107  traditional                5.964030e-05
# 6                 107   foundation                2.789720e-06
# 7                 107  traditional                7.359781e-06
# 8                 107  traditional                1.174267e-06
# 9                 107  traditional                1.002695e-06
# 10                107  traditional                2.484455e-06
# 11                107   foundation                2.393099e-06
# 12                107  traditional                4.354370e-05
# 13                107   foundation                4.887581e-05
# 14                107   foundation                3.353458e-06
# 15                107  traditional                1.205685e-05
#
#     avg_inference_time_seconds_tuned  avg_series_total_time_seconds_tuned  \
# 0                           0.000008                             0.000010
# 1                           0.000045                             0.000047
# 2                           0.232222                             0.232227
# 3                           0.127728                             0.127735
# 4                           0.560590                             0.560641
# 5                           0.510298                             0.510364
# 6                           1.057493                             1.057500
# 7                          26.116691                            26.116711
# 8                           0.000012                             0.000016
# 9                           0.000041                             0.000044
# 10                          0.326988                             0.326995
# 11                          0.141292                             0.141299
# 12                          0.695302                             0.695351
# 13                          0.425304                             0.425359
# 14                          1.089793                             1.089801
# 15                         29.544604                            29.544629
#
#     avg_peak_memory_mb_tuned  n_series_tuned  inference_time_change  \
# 0                   0.147160             107              -0.000007
# 1                   0.156635             107              -0.000039
# 2                  11.481708             107               0.127100
# 3                   1.204708             107              -0.013202
# 4                   0.224347             107               0.213113
# 5                  24.097406             107               0.055246
# 6                   2.203263             107              -0.172014
# 7                   0.579781             107              24.187630
# 8                  45.713576             107              -0.000005
# 9                   0.150764             107              -0.000021
# 10                 11.642643             107               0.212665
# 11                  1.198418             107              -0.017295
# 12                 23.614329             107               0.271841
# 13                  1.060580             107              -0.038963
# 14                  2.204543             107              -0.232149
# 15                  0.564061             107              27.079404
#
#     memory_change_mb
# 0          -0.000214
# 1          -0.000160
# 2           6.088140
# 3           0.010629
# 4           0.004850
# 5           0.044641
# 6           0.386456
# 7          -0.008269
# 8          45.566181
# 9          -0.001320
# 10          4.658139
# 11         -0.039044
# 12         -1.725264
# 13        -11.162968
# 14         -0.173676
# 15         -0.015151

# %%
runtime_tuned_df.to_csv(final_dir / f"{DATASET_KEY}_runtime_tuned.csv", index=False)
runtime_compare_df.to_csv(final_dir / f"{DATASET_KEY}_runtime_compare_baseline_vs_tuned.csv", index=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

for model in compare_df["model"].unique():
    subset = compare_df[compare_df["model"] == model]
    plt.bar(model, subset["smape_improvement"].mean())

plt.title("Average sMAPE Improvement (Baseline → Tuned)")
plt.ylabel("Improvement (positive = better)")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()
